# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.5.4)
# Requirement already satisfied: joblib>=0.11 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.1.1)

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: joblib>=0.11 in /home/docode/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-learn) (1.1.1)

# %%
def load_dataset():
    url = "https://storage.googleapis.com/qwasar-public/track-ds/iris.csv"
    return pd.read_csv(url)

# %%
def summarize_dataset(dataset):
    print("Dataset dimension:")
    print(dataset.shape)
    print("\nFirst 10 rows of dataset:")
    print(dataset.head(10))
    print("\nStatistical summary:")
    print(dataset.describe())
    print("\nClass Distribution:")
    print(dataset.groupby('class').size())

# %%
def print_plot_univariate(dataset):
    dataset.hist()
    plt.tight_layout()
    plt.show()

# %%
from pandas.plotting import scatter_matrix
def print_plot_multivariate(dataset):
    scatter_matrix(dataset)
    plt.tight_layout()
    plt.show()

# %%
def my_print_and_test_models(dataset):
    array = dataset.values
    X = array[:, 0:4]
    y = array[:, 4]
    X_train, X_validation, Y_train, Y_validation = train_test_split(
        X, y, test_size=0.20, random_state=1
    )
    models = []
    models.append(('DecisionTree', DecisionTreeClassifier()))
    models.append(('GaussianNB', GaussianNB()))
    models.append(('KNeighbors', KNeighborsClassifier()))
    models.append(('LogisticRegression', LogisticRegression(solver='liblinear', multi_class='ovr')))
    models.append(('LinearDiscriminant', LinearDiscriminantAnalysis()))
    models.append(('SVM', SVC(gamma='auto')))

    for name, model in models:
        kfold = KFold(n_splits=10, random_state=1, shuffle=True)
        cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
        print(f"{name}: {cv_results.mean():.6f} ({cv_results.std():.6f})")

# %%
# Load the dataset
dataset = load_dataset()

# %%
# Summarize
summarize_dataset(dataset)
# Out:
# Dataset dimension:
# (150, 5)
#
# First 10 rows of dataset:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#
# Statistical summary:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# Class Distribution:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# Univariate plot
print_plot_univariate(dataset)

# %%
# Multivariate plot
print_plot_multivariate(dataset)

# %%
# Evaluate models
my_print_and_test_models(dataset)
# Out:
# DecisionTree: 0.966667 (0.040825)
# GaussianNB: 0.950000 (0.040825)
# KNeighbors: 0.958333 (0.041667)
# LogisticRegression: 0.933333 (0.089753)
# LinearDiscriminant: 0.975000 (0.038188)
# SVM: 0.983333 (0.033333)

# %%
gandalf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3642960d29f> in <module>
# ----> 1 gandalf
#
# NameError: name 'gandalf' is not defined

# %%
# !gandalf
# Out:
#  ██████╗ ██╗    ██╗ █████╗ ███████╗ █████╗ ██████╗    ██╗ ██████╗
# ██╔═══██╗██║    ██║██╔══██╗██╔════╝██╔══██╗██╔══██╗   ██║██╔═══██╗
# ██║   ██║██║ █╗ ██║███████║███████╗███████║██████╔╝   ██║██║   ██║
# ██║▄▄ ██║██║███╗██║██╔══██║╚════██║██╔══██║██╔══██╗   ██║██║   ██║
# ╚██████╔╝╚███╔███╔╝██║  ██║███████║██║  ██║██║  ██║██╗██║╚██████╔╝
#  ╚══▀▀═╝  ╚══╝╚══╝ ╚═╝  ╚═╝╚══════╝╚═╝  ╚═╝╚═╝  ╚═╝╚═╝╚═╝ ╚═════╝
#
# Booting Gandalf v4.0.3-df2e622 (production)
# Loading parameters:  OK
# User rai_s connection: OK
#
#
# <MY-OPEN-THE-IRIS>
# Directory . exists: OK
# Pushing exercise: OK
# Printing your report:
#
#       REPORT        MY-OPEN-THE-IRIS
#
#  Status             SUCCESS
#  Execution Runtime  8.679134
#  Score              [====] 4/4
#
#
# Checks detail Report:
#
#  TEST LOAD DATASET  SUCCESS
#
#
#
#  TEST PRINT PLOT MULTIVARIATE  SUCCESS
#
#
#
#  TEST PRINT PLOT UNIVARIATE  SUCCESS
#
#
#
#  TEST SUMMARIZE DATASET  SUCCESS
#
#
# </MY-OPEN-THE-IRIS>

# %%
# !git add .

# %%
# !git commit -m "Model training for the loaded data"
# Out:
# [dev 287050e] Model training for the loaded data
#  4 files changed, 1307 insertions(+), 19 deletions(-)
#  create mode 100644 iris/.ipynb_checkpoints/iris1-checkpoint.ipynb

# %%
# !git push
# Out:
# Warning: Permanently added 'git.us.qwasar.io,35.202.192.39' (ECDSA) to the list of known hosts.
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 65.98 KiB | 8.25 MiB/s, done.
# Total 7 (delta 2), reused 0 (delta 0)
# remote: . Processing 1 references
# remote: Processed 1 references in total
# To git.us.qwasar.io:my_open_the_iris_191013_goqknt/my_open_the_iris.git
#    878d895..287050e  dev -> dev
